# %% [markdown]
# Ця домашня робота була виконана з використанням додаткового інструменту для візуалізації - AWS QuickSight, що дозволяє швидко створювати візуалізації без використання сторонніх бібліотек, тому результати роботи наступні:

# %% [markdown]
# ![image.png](attachment:365d2ea4-3dce-4615-8892-1ca2e18c0526.png)

# %% [markdown]
# ![image.png](attachment:c0022ec9-86dc-4573-9022-86273d06f855.png)

# %% [markdown]
# ![image.png](attachment:a67f7e59-d906-4670-9ef9-34f8d7bd2915.png)

# %% [markdown]
# ![image.png](attachment:88ae68d2-ea4f-4aa1-9e0f-63f80150f87d.png)

# %% [markdown]
# ![image.png](attachment:8a8c7ea1-869e-49b7-a736-1267b1ac4ec2.png)
